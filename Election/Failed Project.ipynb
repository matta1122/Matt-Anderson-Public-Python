# %%
import sklearn
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("county_statistics.csv")
df = df[["percentage20_Donald_Trump", "percentage20_Joe_Biden", "cases", "TotalPop", "case_rate"]]

df = df.apply(pd.to_numeric, errors='coerce')
df = df.fillna(df.mean())

'''case_rate = df[['TotalPop','cases']]

df.div(case_rate, level=1, fill_value=0, axis=1)

df["case_rate"] = ""
df.to_csv("county_statistics.csv", index=False)

df['case_rate'] = df['TotalPop']/df['cases']

df = df.apply(pd.to_numeric, errors='coerce')
df = df.fillna(df.mean())
df = df.reset_index()'''

predict = "percentage20_Donald_Trump"

X = np.array(df.drop([predict], 1)) #Features
y = np.array(df[predict]) #Labels
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.2)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)
acc = linear.score(x_test, y_test)
print("Your accuracy is", acc)
predictions = linear.predict(x_test) # Gets a list of all predictions

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])


'''
New code that is not from the tutorial that needs to be checked and tested.
df[['case_rate', 'percentage20_Donald_Trump', 'percentage20_Joe_Biden']].groupby(['percentage20_Joe_Biden'], as_index=False).mean().sort_values(by='percentage20_Joe_Biden', ascending=True)

df_sample=df.sample(10)
 
# Make the plot with this subset
plt.plot( 'percentage20_Donald_Trump', 'case_rate', data=df_sample, linestyle='', marker='o', markersize=0.7)
 
# titles
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Overplotting? Sample your data', loc='left')


p = 'case_rate'
style.use("ggplot")
pyplot.scatter(df[p],df["percentage20_Donald_Trump"], markersize=0.7)
pyplot.xlabel(p)
pyplot.ylabel("Donald Trump Percentage")
pyplot.show()'''
# Out:
# 0001
# 0.7021498720834358 [2.8100000e-01 8.7500000e+02 1.5952000e+04 5.4852056e-02] 0.7070000000000001
# 0.6191798452594004 [3.6300000e-01 2.8510000e+03 2.3232400e+05 1.2271655e-02] 0.618
# 0.48548456508670773 [4.9600000e-01 2.5580000e+03 1.7270700e+05 1.4811212e-02] 0.486
# 0.7795993126768626 [2.0400000e-01 9.7500000e+02 3.7159000e+04 2.6238596e-02] 0.7859999999999999
# 0.645785165761698 [3.3700000e-01 3.5430000e+03 1.2128200e+05 2.9212909e-02] 0.633
# 0.7242418677226234 [2.5900000e-01 5.0700000e+02 2.1467000e+04 2.3617646e-02] 0.726
# 0.7343280911482344 [2.4900000e-01 1.0380000e+03 3.3596000e+04 3.0896535e-02] 0.731
# 0.7755766533311177 [2.0800000e-01 4.8200000e+02 1.7596000e+04 2.7392589e-02] 0.7829999999999999
# 0.8087806169212731 [1.7500000e-01 1.2300000e+02 8.1290000e+03 1.5131012e-02] 0.812
# 0.6004628771745628 [3.8200000e-01 2.1600000e+02 5.7480000e+03 3.7578288e-02] 0.608
# 0.8249620540717926 [1.5900000e-01 1.2220000e+03 1.7846000e+04 6.8474728e-02] 0.83
# ...
